# %%
import pandas as pd
import numpy as np
from scipy.io import arff
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
path = '.../KDDTrain+.arff'
data, meta = arff.loadarff(path)
df = pd.DataFrame(data)
for col in df.select_dtypes([object]):
    df[col] = df[col].str.decode('utf-8')
df['label'] = (df[df.columns[-1]] != 'normal').astype(int)

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing (%)': missing_pct.round(2)
})

missing_cols = missing_df[missing_df['Missing Count'] > 0]

if missing_cols.empty:
    print("No missing values found.")
else:
    print(f"Missing values found in {len(missing_cols)} column(s):\n")
    print(missing_cols.to_string())

print(f"Total rows       : {len(df)}")
print(f"Total columns    : {df.shape[1]}")
print(f"Total missing    : {df.isnull().sum().sum()}")
print(f"Affected columns : {len(missing_cols)}")
# Out:
# No missing values found.
# Total rows       : 125973
# Total columns    : 43
# Total missing    : 0
# Affected columns : 0

# %%
selected_features = [
    'num_access_files',
    'dst_bytes',
    'dst_host_count',
    'num_compromised',
    'dst_host_same_srv_rate',
    'same_srv_rate',
    'dst_host_srv_count',
    'serror_rate',
    'count',
    'rerror_rate',
    'dst_host_srv_rerror_rate',
    'dst_host_srv_serror_rate',
    'dst_host_rerror_rate',
    'dst_host_same_src_port_rate',
    'dst_host_serror_rate',
    'num_file_creations',
    'srv_count',
    'srv_serror_rate',
    'srv_rerror_rate',
    'srv_diff_host_rate',
    'wrong_fragment',
    'urgent',
    'src_bytes',
    'hot',
    'num_failed_logins'
]

print(f"Total features: {len(selected_features)}")
# Out:
# Total features: 25

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# %%
X = df[selected_features].values
y = df.iloc[:, 42].values

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import tensorflow as tf

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, TimeDistributed, Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time
class JaspenCorrelation(tf.keras.layers.Layer):
    def call(self, inputs):
        t, r = inputs  # t: (None, feat_dim), r: (None, REF_COUNT, feat_dim)
        t_exp = tf.expand_dims(t, 1)              # (None, 1, feat_dim)
        dot = tf.reduce_sum(t_exp * r, axis=2)    # (None, REF_COUNT)

        sum_t = tf.reduce_sum(t_exp, axis=2)      # (None, 1)
        sum_r = tf.reduce_sum(r, axis=2)          # (None, REF_COUNT)

        n = tf.cast(tf.shape(t)[1], tf.float32)
        corr = (n * dot - sum_t * sum_r) / (tf.sqrt(n * sum_t) * tf.sqrt(n * sum_r) + 1e-8)
        return tf.maximum(corr, 0.0)              # only positive correlation
def create_model(ref_count, seq_len, channels, num_classes, is_multiclass):
    test_input = Input(shape=(seq_len, channels), name="test_input")
    reference_input = Input(shape=(ref_count, seq_len, channels), name="reference_input")

    shared_cnn = tf.keras.Sequential([
        Conv1D(64, 3, activation='relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, activation='relu'),
        MaxPooling1D(2),
        Flatten()
    ], name='shared_cnn')

    test_encoded = shared_cnn(test_input)                     # (None, feat_dim)
    reference_encoded = TimeDistributed(shared_cnn)(reference_input)  # (None, REF_COUNT, feat_dim)

    corr = JaspenCorrelation()([test_encoded, reference_encoded])     # (None, REF_COUNT)
    agg = Lambda(lambda x: tf.reduce_mean(x, axis=1, keepdims=True))(corr)  # (None, 1)

    x = Dense(128, activation='relu')(agg)

    if is_multiclass:
        output = Dense(num_classes, activation='softmax')(x)
        loss = 'categorical_crossentropy'
    else:
        output = Dense(num_classes, activation='sigmoid')(x)
        loss = 'binary_crossentropy'

    model = Model(inputs=[test_input, reference_input], outputs=output)
    return model, loss
def calculate_all_metrics(y_true, y_pred, is_multiclass, threshold=0.5):
    """
    Returns dict with ADA, Accuracy, Precision, Recall, F1_Score (in %).
    - Multiclass (one-hot): argmax
    - Binary/multilabel: threshold on sigmoid
    """
    if is_multiclass:
        y_true_cls = np.argmax(y_true, axis=1)
        y_pred_cls = np.argmax(y_pred, axis=1)
        acc = accuracy_score(y_true_cls, y_pred_cls)
        prec = precision_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        rec = recall_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        f1 = f1_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
    else:

        y_pred_bin = (y_pred >= threshold).astype(int)

        average = 'binary' if y_true.shape[1] == 1 else 'macro'
        acc = accuracy_score(y_true, y_pred_bin)
        prec = precision_score(y_true, y_pred_bin, average=average, zero_division=0)
        rec = recall_score(y_true, y_pred_bin, average=average, zero_division=0)
        f1 = f1_score(y_true, y_pred_bin, average=average, zero_division=0)
    return {
        'ADA': acc * 100.0,
        'Accuracy': acc * 100.0,
        'Precision': prec * 100.0,
        'Recall': rec * 100.0,
        'F1_Score': f1 * 100.0
    }
def calculate_space_per_instance_broadcast(X_sample, y_sample):
    return (X_sample.nbytes + y_sample.nbytes) / (1024 * 1024)

def reference_set_size_mb(reference_set):
    return reference_set.nbytes / (1024 * 1024)

def measure_single_instance_time(model, X_sample, reference_set, num_trials=5):
    ref_input = np.broadcast_to(reference_set[np.newaxis, ...],
                                (1,) + reference_set.shape)
    # warmup
    _ = model.predict([X_sample, ref_input], verbose=0)
    times = []
    for _ in range(num_trials):
        t0 = time.time()
        _ = model.predict([X_sample, ref_input], verbose=0)
        times.append((time.time() - t0) * 1000.0)
    return float(np.mean(times))

# -----------------------------------------------------
# 5) Main experiment loop (REF_COUNT = 50, broadcast)
# -----------------------------------------------------
def run_experiments_with_fixed_ref(X, y, instance_numbers=None, ref_count_fixed=20,
                                   epochs=10, batch_size=256, test_size=0.2, random_state=42):
    assert X.shape[0] == y.shape[0], "X and y must have the same number of sample"
    N, SEQ_LEN, CHANNELS = X.shape[0], X.shape[1], X.shape[2]
    NUM_CLASSES = y.shape[1]
    is_multiclass = (NUM_CLASSES > 1) and (np.all((y == 0) | (y == 1)) and np.all(y.sum(axis=1) == 1))

    # default instance_numbers
    if instance_numbers is None:
        instance_numbers = [10000, 20000, 30000, 40000, 50000,
                            60000, 70000, 80000, 90000, 100000]

    results = {
        'instances': [],
        'ref_count_used': [],
        'ADA': [],
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1_score': [],
        'training_time': [],
        'time_complexity_ms': [],
        'space_complexity_mb': []
    }
    X = X.astype(np.float32)
    y = y.astype(np.float32)

    for n_instances in instance_numbers:
        if n_instances > N:
            print(f"Skip N={n_instances}: not enough data (dataset size={N})")
            continue

        print("\n" + "="*70)
        print(f"Running experiment with N = {n_instances} (REF_COUNT fixed = {ref_count_fixed})")
        print("="*70)
        X_sub = X[:n_instances]
        y_sub = y[:n_instances]
        if is_multiclass:
            y_strat = np.argmax(y_sub, axis=1)
        else:
            y_strat = y_sub.squeeze()

            if y_sub.ndim == 2 and y_sub.shape[1] > 1:
                y_strat = None

        X_train_subset, X_test_subset, y_train_subset, y_test_subset = train_test_split(
            X_sub, y_sub, test_size=test_size, stratify=y_strat, random_state=random_state
        )

        ref_count = min(ref_count_fixed, len(X_train_subset))
        reference_set = X_train_subset[:ref_count]

        reference_input_train_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_train_subset.shape[0],) + reference_set.shape
        )
        reference_input_test_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_test_subset.shape[0],) + reference_set.shape
        )

        model, loss = create_model(ref_count, SEQ_LEN, CHANNELS, NUM_CLASSES, is_multiclass)
        model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
        X_sample = X_train_subset[0:1]
        y_sample = y_train_subset[0:1]

        space_per_instance = calculate_space_per_instance_broadcast(X_sample, y_sample)

        S_com = n_instances * space_per_instance + reference_set_size_mb(reference_set)

        t0 = time.time()
        history = model.fit(
            [X_train_subset, reference_input_train_subset],
            y_train_subset,
            validation_data=([X_test_subset, reference_input_test_subset], y_test_subset),
            epochs=epochs,
            batch_size=batch_size,
            verbose=1
        )
        train_time = time.time() - t0
        pred_start = time.time()
        y_pred = model.predict([X_test_subset, reference_input_test_subset], verbose=0)
        metrics = calculate_all_metrics(y_test_subset, y_pred, is_multiclass)
        pred_end = time.time()
        prediction_time = pred_end - pred_start
        tpi = measure_single_instance_time(model, X_sample, reference_set, num_trials=5)
        T_com = n_instances * tpi
        results['instances'].append(n_instances)
        results['ref_count_used'].append(ref_count)
        results['ADA'].append(metrics['ADA'])
        results['accuracy'].append(metrics['Accuracy'])
        results['precision'].append(metrics['Precision'])
        results['recall'].append(metrics['Recall'])
        results['f1_score'].append(metrics['F1_Score'])
        results['training_time'].append(train_time)
        results['time_complexity_ms'].append(T_com)
        results['space_complexity_mb'].append(S_com)
        results.setdefault('prediction_time', []).append(prediction_time)
        results.setdefault('history', []).append(history.history)  # TAMBAHKAN INI
        print(f"REF_COUNT used          : {ref_count}")
        print(f"Train time (s)          : {train_time:.2f}")
        print(f"ADA / Acc / Prec / Rec / F1 (%): "
              f"{metrics['ADA']:.2f} / {metrics['Accuracy']:.2f} / {metrics['Precision']:.2f} / "
              f"{metrics['Recall']:.2f} / {metrics['F1_Score']:.2f}")
        print(f"T_com (ms)              : {T_com:.2f}")
        print(f"S_com (MB)              : {S_com:.2f}")
        del model
        tf.keras.backend.clear_session()

    return results
def display_results_table(results):
    print("\n" + "="*120)
    print("EXPERIMENT RESULTS WITH FIXED REF_COUNT (50) AND BROADCAST")
    print("="*120)
    print(f"{'Instances':<10} {'REF_COUNT':<10} {'ADA (%)':<8} {'Acc (%)':<8} {'Prec (%)':<9} "
          f"{'Rec (%)':<8} {'F1 (%)':<8} {'Train(s)':<9} {'T_com(ms)':<10} {'S_com(MB)':<10}")
    print("-"*120)
    for i in range(len(results['instances'])):
        print(f"{results['instances'][i]:<10} "
              f"{results['ref_count_used'][i]:<10} "
              f"{results['ADA'][i]:<8.2f} "
              f"{results['accuracy'][i]:<8.2f} "
              f"{results['precision'][i]:<9.2f} "
              f"{results['recall'][i]:<8.2f} "
              f"{results['f1_score'][i]:<8.2f} "
              f"{results['training_time'][i]:<9.2f} "
              f"{results['time_complexity_ms'][i]:<10.2f} "
              f"{results['space_complexity_mb'][i]:<10.2f}"
              f"{results['prediction_time'][i]:<10.2f}")

# %%
print(X.shape, y.shape, X.dtype, y.dtype)
# Out:
# (125973, 25) (125973,) float64 int64

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

def ensure_3d_X(X):
    X = np.asarray(X)
    if X.ndim == 2:   # (N, F) -> (N, F, 1)
        X = X.astype(np.float32)[..., np.newaxis]
    elif X.ndim == 3:
        X = X.astype(np.float32)
    else:
        raise ValueError(f"X must 2D/3D. get: {X.shape}")
    return X

def ensure_y_shape(y):
    y = np.asarray(y)
    if y.dtype == object:
        le = LabelEncoder()
        y = le.fit_transform(y)
    if not np.issubdtype(y.dtype, np.integer):
        y = y.astype(int)
    classes = np.unique(y)
    if len(classes) == 2 and set(classes) <= {0,1}:
        # Binary -> (N,1)
        y = y.reshape(-1, 1).astype(np.float32)
    else:
        # Multiclass -> one-hot
        y = to_categorical(y.astype(int)).astype(np.float32)
    return y

# ====== APPLY FIX ======
X = ensure_3d_X(X)   # (125973, 18) -> (125973, 18, 1)
y = ensure_y_shape(y)

print("After fix:", X.shape, X.dtype, "|", y.shape, y.dtype)
print("Unique y classes:", (int(y.shape[1]) if y.ndim==2 else 1), "class(es)")
instance_numbers = [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
instance_numbers = [n for n in instance_numbers if n <= X.shape[0]]

results = run_experiments_with_fixed_ref(
    X, y,
    instance_numbers=instance_numbers,
    ref_count_fixed=20,
    epochs=10,
    batch_size=256
)
# Out:
# After fix: (125973, 25, 1) float32 | (125973, 1) float32
# Unique y classes: 1 class(es)
#
# ======================================================================
# Running experiment with N = 10000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 241ms/step - accuracy: 0.5263 - loss: 0.6937 - val_accuracy: 0.5305 - val_loss: 0.5568
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7261 - loss: 0.5787 - val_accuracy: 0.9125 - val_loss: 0.5337
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8941 - loss: 0.5485 - val_accuracy: 0.8970 - val_loss: 0.4728
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9129 - loss: 0.5030 - val_accuracy: 0.9145 - val_loss: 0.4329
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9096 - loss: 0.4725 - val_accuracy: 0.9060 - val_loss: 0.4088
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9029 - loss: 0.4359 - val_accuracy: 0.9100 - val_loss: 0.4203
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9016 - loss: 0.4621 - val_accuracy: 0.9075 - val_loss: 0.3720
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9022 - loss: 0.4244 - val_accuracy: 0.9075 - val_loss: 0.3667
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9000 - loss: 0.4246 - val_accuracy: 0.9265 - val_loss: 0.3543
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9078 - loss: 0.4201 - val_accuracy: 0.9000 - val_loss: 0.3649
# REF_COUNT used          : 20
# Train time (s)          : 22.69
# ADA / Acc / Prec / Rec / F1 (%): 90.00 / 90.00 / 84.04 / 97.24 / 90.16
# T_com (ms)              : 722399.23
# S_com (MB)              : 0.99
#
# ======================================================================
# Running experiment with N = 20000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 130ms/step - accuracy: 0.7214 - loss: 0.5914 - val_accuracy: 0.9160 - val_loss: 0.5395
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9029 - loss: 0.4707 - val_accuracy: 0.9070 - val_loss: 0.3826
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9040 - loss: 0.3734 - val_accuracy: 0.9168 - val_loss: 0.3345
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9061 - loss: 0.3452 - val_accuracy: 0.8085 - val_loss: 0.4134
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8989 - loss: 0.3368 - val_accuracy: 0.9137 - val_loss: 0.3038
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9014 - loss: 0.3368 - val_accuracy: 0.9122 - val_loss: 0.3038
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9089 - loss: 0.3135 - val_accuracy: 0.9032 - val_loss: 0.3212
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8901 - loss: 0.3511 - val_accuracy: 0.9095 - val_loss: 0.2800
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8962 - loss: 0.3209 - val_accuracy: 0.9143 - val_loss: 0.3051
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8804 - loss: 0.3529 - val_accuracy: 0.9093 - val_loss: 0.2981
# REF_COUNT used          : 20
# Train time (s)          : 26.59
# ADA / Acc / Prec / Rec / F1 (%): 90.92 / 90.92 / 85.07 / 97.64 / 90.92
# T_com (ms)              : 1451382.64
# S_com (MB)              : 1.99
#
# ======================================================================
# Running experiment with N = 30000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.5508 - loss: 0.8741 - val_accuracy: 0.7222 - val_loss: 0.5792
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8649 - loss: 0.5190 - val_accuracy: 0.8958 - val_loss: 0.4944
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9047 - loss: 0.4273 - val_accuracy: 0.9153 - val_loss: 0.3971
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9031 - loss: 0.3573 - val_accuracy: 0.8922 - val_loss: 0.3124
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9058 - loss: 0.2801 - val_accuracy: 0.9108 - val_loss: 0.2602
# Epoch 6/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9106 - loss: 0.2503 - val_accuracy: 0.9130 - val_loss: 0.2368
# Epoch 7/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9157 - loss: 0.2333 - val_accuracy: 0.9188 - val_loss: 0.2225
# Epoch 8/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9190 - loss: 0.2239 - val_accuracy: 0.9217 - val_loss: 0.2145
# Epoch 9/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9224 - loss: 0.2164 - val_accuracy: 0.9208 - val_loss: 0.2089
# Epoch 10/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9251 - loss: 0.2093 - val_accuracy: 0.9288 - val_loss: 0.2012
# REF_COUNT used          : 20
# Train time (s)          : 32.53
# ADA / Acc / Prec / Rec / F1 (%): 92.88 / 92.88 / 91.05 / 94.00 / 92.50
# T_com (ms)              : 2180675.98
# S_com (MB)              : 2.98
#
# ======================================================================
# Running experiment with N = 40000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 44ms/step - accuracy: 0.6122 - loss: 0.7468 - val_accuracy: 0.8911 - val_loss: 0.5830
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9079 - loss: 0.4709 - val_accuracy: 0.9193 - val_loss: 0.4238
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9150 - loss: 0.3565 - val_accuracy: 0.9059 - val_loss: 0.3366
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9050 - loss: 0.2918 - val_accuracy: 0.9126 - val_loss: 0.2626
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9175 - loss: 0.2462 - val_accuracy: 0.9176 - val_loss: 0.2389
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9201 - loss: 0.2284 - val_accuracy: 0.9239 - val_loss: 0.2600
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9185 - loss: 0.2360 - val_accuracy: 0.9199 - val_loss: 0.2207
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9234 - loss: 0.2145 - val_accuracy: 0.9227 - val_loss: 0.2091
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9273 - loss: 0.2053 - val_accuracy: 0.9250 - val_loss: 0.2023
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9305 - loss: 0.1988 - val_accuracy: 0.9320 - val_loss: 0.1969
# REF_COUNT used          : 20
# Train time (s)          : 33.61
# ADA / Acc / Prec / Rec / F1 (%): 93.20 / 93.20 / 91.35 / 94.42 / 92.86
# T_com (ms)              : 2833703.99
# S_com (MB)              : 3.97
#
# ======================================================================
# Running experiment with N = 50000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 60ms/step - accuracy: 0.8013 - loss: 0.5315 - val_accuracy: 0.8961 - val_loss: 0.3835
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8951 - loss: 0.3429 - val_accuracy: 0.9024 - val_loss: 0.2941
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8906 - loss: 0.3364 - val_accuracy: 0.9010 - val_loss: 0.3306
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8967 - loss: 0.3244 - val_accuracy: 0.8992 - val_loss: 0.2906
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9079 - loss: 0.2901 - val_accuracy: 0.9129 - val_loss: 0.2723
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9133 - loss: 0.2879 - val_accuracy: 0.9243 - val_loss: 0.2583
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9200 - loss: 0.2770 - val_accuracy: 0.9182 - val_loss: 0.2652
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9188 - loss: 0.2708 - val_accuracy: 0.9121 - val_loss: 0.2565
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9287 - loss: 0.2520 - val_accuracy: 0.9387 - val_loss: 0.2552
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9370 - loss: 0.2301 - val_accuracy: 0.9258 - val_loss: 0.2266
# REF_COUNT used          : 20
# Train time (s)          : 43.21
# ADA / Acc / Prec / Rec / F1 (%): 92.58 / 92.58 / 88.72 / 96.44 / 92.42
# T_com (ms)              : 3729095.46
# S_com (MB)              : 4.96
#
# ======================================================================
# Running experiment with N = 60000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 55ms/step - accuracy: 0.8570 - loss: 0.4886 - val_accuracy: 0.9200 - val_loss: 0.3493
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9113 - loss: 0.3016 - val_accuracy: 0.9113 - val_loss: 0.2525
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9235 - loss: 0.2247 - val_accuracy: 0.9258 - val_loss: 0.2137
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9293 - loss: 0.2064 - val_accuracy: 0.9308 - val_loss: 0.1954
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9352 - loss: 0.1822 - val_accuracy: 0.9355 - val_loss: 0.1818
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9379 - loss: 0.1681 - val_accuracy: 0.9326 - val_loss: 0.1698
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9414 - loss: 0.1548 - val_accuracy: 0.9392 - val_loss: 0.1534
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9448 - loss: 0.1458 - val_accuracy: 0.9435 - val_loss: 0.1429
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9459 - loss: 0.1385 - val_accuracy: 0.9485 - val_loss: 0.1390
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9476 - loss: 0.1347 - val_accuracy: 0.9517 - val_loss: 0.1324
# REF_COUNT used          : 20
# Train time (s)          : 49.37
# ADA / Acc / Prec / Rec / F1 (%): 95.17 / 95.17 / 95.55 / 94.05 / 94.80
# T_com (ms)              : 4269793.51
# S_com (MB)              : 5.95
#
# ======================================================================
# Running experiment with N = 70000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - accuracy: 0.7424 - loss: 0.6034 - val_accuracy: 0.9004 - val_loss: 0.4766
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8784 - loss: 0.4436 - val_accuracy: 0.9057 - val_loss: 0.2991
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9046 - loss: 0.3024 - val_accuracy: 0.9124 - val_loss: 0.2680
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9153 - loss: 0.2672 - val_accuracy: 0.9224 - val_loss: 0.2387
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9212 - loss: 0.2491 - val_accuracy: 0.9303 - val_loss: 0.2057
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9289 - loss: 0.2053 - val_accuracy: 0.9346 - val_loss: 0.1929
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9342 - loss: 0.1898 - val_accuracy: 0.9376 - val_loss: 0.1794
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9372 - loss: 0.1753 - val_accuracy: 0.9411 - val_loss: 0.1646
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9406 - loss: 0.1613 - val_accuracy: 0.9446 - val_loss: 0.1507
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9451 - loss: 0.1495 - val_accuracy: 0.9484 - val_loss: 0.1417
# REF_COUNT used          : 20
# Train time (s)          : 55.33
# ADA / Acc / Prec / Rec / F1 (%): 94.84 / 94.84 / 94.78 / 94.16 / 94.47
# T_com (ms)              : 5053660.39
# S_com (MB)              : 6.94
#
# ======================================================================
# Running experiment with N = 80000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.8196 - loss: 0.6030 - val_accuracy: 0.9051 - val_loss: 0.4369
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8901 - loss: 0.4350 - val_accuracy: 0.8770 - val_loss: 0.3530
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8890 - loss: 0.3292 - val_accuracy: 0.8949 - val_loss: 0.2814
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8953 - loss: 0.2972 - val_accuracy: 0.8981 - val_loss: 0.2622
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8999 - loss: 0.2834 - val_accuracy: 0.9069 - val_loss: 0.2432
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9145 - loss: 0.2273 - val_accuracy: 0.9232 - val_loss: 0.2173
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9286 - loss: 0.2058 - val_accuracy: 0.9347 - val_loss: 0.1997
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9366 - loss: 0.1909 - val_accuracy: 0.9375 - val_loss: 0.1862
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9404 - loss: 0.1749 - val_accuracy: 0.9436 - val_loss: 0.1638
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9446 - loss: 0.1560 - val_accuracy: 0.9467 - val_loss: 0.1494
# REF_COUNT used          : 20
# Train time (s)          : 56.58
# ADA / Acc / Prec / Rec / F1 (%): 94.67 / 94.67 / 93.79 / 94.86 / 94.32
# T_com (ms)              : 5685153.96
# S_com (MB)              : 7.94
#
# ======================================================================
# Running experiment with N = 90000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 20s 42ms/step - accuracy: 0.7971 - loss: 0.5427 - val_accuracy: 0.9105 - val_loss: 0.3366
# Epoch 2/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8886 - loss: 0.3472 - val_accuracy: 0.9207 - val_loss: 0.2571
# Epoch 3/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8897 - loss: 0.3127 - val_accuracy: 0.9051 - val_loss: 0.2572
# Epoch 4/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8957 - loss: 0.2946 - val_accuracy: 0.9206 - val_loss: 0.2343
# Epoch 5/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9049 - loss: 0.2802 - val_accuracy: 0.9327 - val_loss: 0.2203
# Epoch 6/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9108 - loss: 0.2690 - val_accuracy: 0.9350 - val_loss: 0.2062
# Epoch 7/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9214 - loss: 0.2463 - val_accuracy: 0.9375 - val_loss: 0.1933
# Epoch 8/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9323 - loss: 0.2207 - val_accuracy: 0.8578 - val_loss: 0.3779
# Epoch 9/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9321 - loss: 0.2160 - val_accuracy: 0.9422 - val_loss: 0.1717
# Epoch 10/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9403 - loss: 0.2019 - val_accuracy: 0.8438 - val_loss: 0.4278
# REF_COUNT used          : 20
# Train time (s)          : 66.37
# ADA / Acc / Prec / Rec / F1 (%): 84.38 / 84.38 / 82.16 / 84.90 / 83.51
# T_com (ms)              : 6503348.35
# S_com (MB)              : 8.93
#
# ======================================================================
# Running experiment with N = 100000 (REF_COUNT fixed = 20)
# ======================================================================
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.7192 - loss: 0.6449 - val_accuracy: 0.8740 - val_loss: 0.3526
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8936 - loss: 0.2843 - val_accuracy: 0.8726 - val_loss: 0.3310
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9168 - loss: 0.2261 - val_accuracy: 0.9234 - val_loss: 0.2173
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9258 - loss: 0.2083 - val_accuracy: 0.9241 - val_loss: 0.2055
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9291 - loss: 0.2002 - val_accuracy: 0.9273 - val_loss: 0.1966
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9332 - loss: 0.1865 - val_accuracy: 0.9273 - val_loss: 0.1938
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9387 - loss: 0.1734 - val_accuracy: 0.9380 - val_loss: 0.1727
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9414 - loss: 0.1667 - val_accuracy: 0.9416 - val_loss: 0.1656
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9446 - loss: 0.1604 - val_accuracy: 0.9470 - val_loss: 0.1535
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9479 - loss: 0.1543 - val_accuracy: 0.9520 - val_loss: 0.1511
# REF_COUNT used          : 20
# Train time (s)          : 71.54
# ADA / Acc / Prec / Rec / F1 (%): 95.19 / 95.19 / 96.26 / 93.31 / 94.76
# T_com (ms)              : 7137103.08
# S_com (MB)              : 9.92

# %%
display_results_table(results)
# Out:
# ========================================================================================================================
# EXPERIMENT RESULTS WITH FIXED REF_COUNT (50) AND BROADCAST
# ========================================================================================================================
# Instances  REF_COUNT  ADA (%)  Acc (%)  Prec (%)  Rec (%)  F1 (%)   Train(s)  T_com(ms)  S_com(MB)
# ------------------------------------------------------------------------------------------------------------------------
# 10000      20         90.00    90.00    84.04     97.24    90.16    22.69     722399.23  0.99      4.03
# 20000      20         90.92    90.92    85.07     97.64    90.92    26.59     1451382.64 1.99      1.94
# 30000      20         92.88    92.88    91.05     94.00    92.50    32.53     2180675.98 2.98      4.07
# 40000      20         93.20    93.20    91.35     94.42    92.86    33.61     2833703.99 3.97      2.45
# 50000      20         92.58    92.58    88.72     96.44    92.42    43.21     3729095.46 4.96      4.30
# 60000      20         95.17    95.17    95.55     94.05    94.80    49.37     4269793.51 5.95      2.66
# 70000      20         94.84    94.84    94.78     94.16    94.47    55.33     5053660.39 6.94      4.63
# 80000      20         94.67    94.67    93.79     94.86    94.32    56.58     5685153.96 7.94      3.05
# 90000      20         84.38    84.38    82.16     84.90    83.51    66.37     6503348.35 8.93      4.92
# 100000     20         95.19    95.19    96.26     93.31    94.76    71.54     7137103.08 9.92      3.27

# %%
import matplotlib.pyplot as plt

for i, hist in enumerate(results['history']):
    n = results['instances'][i]

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(hist['accuracy'], label='Train Accuracy')
    axes[0].plot(hist['val_accuracy'], label='Val Accuracy')
    axes[0].set_title(f'Accuracy - {n//1000}k instances')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(False)

    axes[1].plot(hist['loss'], label='Train Loss')
    axes[1].plot(hist['val_loss'], label='Val Loss')
    axes[1].set_title(f'Loss - {n//1000}k instances')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(False)

    plt.tight_layout()
    plt.show()
