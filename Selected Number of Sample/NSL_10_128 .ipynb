# %%
import pandas as pd
import numpy as np
from scipy.io import arff
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
path = '.../KDDTrain+.arff'
data, meta = arff.loadarff(path)
df = pd.DataFrame(data)
for col in df.select_dtypes([object]):
    df[col] = df[col].str.decode('utf-8')
df['label'] = (df[df.columns[-1]] != 'normal').astype(int)

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing (%)': missing_pct.round(2)
})

missing_cols = missing_df[missing_df['Missing Count'] > 0]

if missing_cols.empty:
    print("No missing values found.")
else:
    print(f"Missing values found in {len(missing_cols)} column(s):\n")
    print(missing_cols.to_string())

print(f"Total rows       : {len(df)}")
print(f"Total columns    : {df.shape[1]}")
print(f"Total missing    : {df.isnull().sum().sum()}")
print(f"Affected columns : {len(missing_cols)}")
# Out:
# No missing values found.
# Total rows       : 125973
# Total columns    : 43
# Total missing    : 0
# Affected columns : 0

# %%
selected_features = [
    'num_access_files',
    'dst_bytes',
    'dst_host_count',
    'num_compromised',
    'dst_host_same_srv_rate',
    'same_srv_rate',
    'dst_host_srv_count',
    'serror_rate',
    'count',
    'rerror_rate',
    'dst_host_srv_rerror_rate',
    'dst_host_srv_serror_rate',
    'dst_host_rerror_rate',
    'dst_host_same_src_port_rate',
    'dst_host_serror_rate',
    'num_file_creations',
    'srv_count',
    'srv_serror_rate',
    'srv_rerror_rate',
    'srv_diff_host_rate',
    'wrong_fragment',
    'urgent',
    'src_bytes',
    'hot',
    'num_failed_logins'
]

print(f"Total features: {len(selected_features)}")
# Out:
# Total features: 25

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# %%
X = df[selected_features].values
y = df.iloc[:, 42].values

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import tensorflow as tf
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, TimeDistributed, Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time
class JaspenCorrelation(tf.keras.layers.Layer):
    def call(self, inputs):
        t, r = inputs  # t: (None, feat_dim), r: (None, REF_COUNT, feat_dim)
        t_exp = tf.expand_dims(t, 1)              # (None, 1, feat_dim)
        dot = tf.reduce_sum(t_exp * r, axis=2)    # (None, REF_COUNT)

        sum_t = tf.reduce_sum(t_exp, axis=2)      # (None, 1)
        sum_r = tf.reduce_sum(r, axis=2)          # (None, REF_COUNT)

        n = tf.cast(tf.shape(t)[1], tf.float32)
        corr = (n * dot - sum_t * sum_r) / (tf.sqrt(n * sum_t) * tf.sqrt(n * sum_r) + 1e-8)
        return tf.maximum(corr, 0.0)              # only positive correlation
def create_model(ref_count, seq_len, channels, num_classes, is_multiclass):
    test_input = Input(shape=(seq_len, channels), name="test_input")
    reference_input = Input(shape=(ref_count, seq_len, channels), name="reference_input")

    shared_cnn = tf.keras.Sequential([
        Conv1D(64, 3, activation='relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, activation='relu'),
        MaxPooling1D(2),
        Flatten()
    ], name='shared_cnn')

    test_encoded = shared_cnn(test_input)                     # (None, feat_dim)
    reference_encoded = TimeDistributed(shared_cnn)(reference_input)  # (None, REF_COUNT, feat_dim)

    corr = JaspenCorrelation()([test_encoded, reference_encoded])     # (None, REF_COUNT)
    agg = Lambda(lambda x: tf.reduce_mean(x, axis=1, keepdims=True))(corr)  # (None, 1)

    x = Dense(128, activation='relu')(agg)

    if is_multiclass:
        output = Dense(num_classes, activation='softmax')(x)
        loss = 'categorical_crossentropy'
    else:
        output = Dense(num_classes, activation='sigmoid')(x)
        loss = 'binary_crossentropy'

    model = Model(inputs=[test_input, reference_input], outputs=output)
    return model, loss
def calculate_all_metrics(y_true, y_pred, is_multiclass, threshold=0.5):
    """
    Returns dict with ADA, Accuracy, Precision, Recall, F1_Score (in %).
    - Multiclass (one-hot): argmax
    - Binary/multilabel: threshold on sigmoid
    """
    if is_multiclass:
        y_true_cls = np.argmax(y_true, axis=1)
        y_pred_cls = np.argmax(y_pred, axis=1)
        acc = accuracy_score(y_true_cls, y_pred_cls)
        prec = precision_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        rec = recall_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        f1 = f1_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
    else:

        y_pred_bin = (y_pred >= threshold).astype(int)

        average = 'binary' if y_true.shape[1] == 1 else 'macro'
        acc = accuracy_score(y_true, y_pred_bin)
        prec = precision_score(y_true, y_pred_bin, average=average, zero_division=0)
        rec = recall_score(y_true, y_pred_bin, average=average, zero_division=0)
        f1 = f1_score(y_true, y_pred_bin, average=average, zero_division=0)
    return {
        'ADA': acc * 100.0,
        'Accuracy': acc * 100.0,
        'Precision': prec * 100.0,
        'Recall': rec * 100.0,
        'F1_Score': f1 * 100.0
    }
def calculate_space_per_instance_broadcast(X_sample, y_sample):
    return (X_sample.nbytes + y_sample.nbytes) / (1024 * 1024)

def reference_set_size_mb(reference_set):
    return reference_set.nbytes / (1024 * 1024)

def measure_single_instance_time(model, X_sample, reference_set, num_trials=5):
    ref_input = np.broadcast_to(reference_set[np.newaxis, ...],
                                (1,) + reference_set.shape)
    # warmup
    _ = model.predict([X_sample, ref_input], verbose=0)
    times = []
    for _ in range(num_trials):
        t0 = time.time()
        _ = model.predict([X_sample, ref_input], verbose=0)
        times.append((time.time() - t0) * 1000.0)
    return float(np.mean(times))

# -----------------------------------------------------
# 5) Main experiment loop (REF_COUNT = 50, broadcast)
# -----------------------------------------------------
def run_experiments_with_fixed_ref(X, y, instance_numbers=None, ref_count_fixed=20,
                                   epochs=10, batch_size=256, test_size=0.2, random_state=42):
    assert X.shape[0] == y.shape[0], "X and y must have the same number of sample"
    N, SEQ_LEN, CHANNELS = X.shape[0], X.shape[1], X.shape[2]
    NUM_CLASSES = y.shape[1]
    is_multiclass = (NUM_CLASSES > 1) and (np.all((y == 0) | (y == 1)) and np.all(y.sum(axis=1) == 1))

    # default instance_numbers
    if instance_numbers is None:
        instance_numbers = [10000, 20000, 30000, 40000, 50000,
                            60000, 70000, 80000, 90000, 100000]

    results = {
        'instances': [],
        'ref_count_used': [],
        'ADA': [],
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1_score': [],
        'training_time': [],
        'time_complexity_ms': [],
        'space_complexity_mb': []
    }
    X = X.astype(np.float32)
    y = y.astype(np.float32)

    for n_instances in instance_numbers:
        if n_instances > N:
            print(f"Skip N={n_instances}: not enough data (dataset size={N})")
            continue

        print("\n" + "="*70)
        print(f"Running experiment with N = {n_instances} (REF_COUNT fixed = {ref_count_fixed})")
        print("="*70)
        X_sub = X[:n_instances]
        y_sub = y[:n_instances]
        if is_multiclass:
            y_strat = np.argmax(y_sub, axis=1)
        else:
            y_strat = y_sub.squeeze()

            if y_sub.ndim == 2 and y_sub.shape[1] > 1:
                y_strat = None

        X_train_subset, X_test_subset, y_train_subset, y_test_subset = train_test_split(
            X_sub, y_sub, test_size=test_size, stratify=y_strat, random_state=random_state
        )

        ref_count = min(ref_count_fixed, len(X_train_subset))
        reference_set = X_train_subset[:ref_count]

        reference_input_train_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_train_subset.shape[0],) + reference_set.shape
        )
        reference_input_test_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_test_subset.shape[0],) + reference_set.shape
        )

        model, loss = create_model(ref_count, SEQ_LEN, CHANNELS, NUM_CLASSES, is_multiclass)
        model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
        X_sample = X_train_subset[0:1]
        y_sample = y_train_subset[0:1]

        space_per_instance = calculate_space_per_instance_broadcast(X_sample, y_sample)

        S_com = n_instances * space_per_instance + reference_set_size_mb(reference_set)

        t0 = time.time()
        history = model.fit(
            [X_train_subset, reference_input_train_subset],
            y_train_subset,
            validation_data=([X_test_subset, reference_input_test_subset], y_test_subset),
            epochs=epochs,
            batch_size=batch_size,
            verbose=1
        )
        train_time = time.time() - t0
        pred_start = time.time()
        y_pred = model.predict([X_test_subset, reference_input_test_subset], verbose=0)
        metrics = calculate_all_metrics(y_test_subset, y_pred, is_multiclass)
        pred_end = time.time()
        prediction_time = pred_end - pred_start
        tpi = measure_single_instance_time(model, X_sample, reference_set, num_trials=5)
        T_com = n_instances * tpi
        results['instances'].append(n_instances)
        results['ref_count_used'].append(ref_count)
        results['ADA'].append(metrics['ADA'])
        results['accuracy'].append(metrics['Accuracy'])
        results['precision'].append(metrics['Precision'])
        results['recall'].append(metrics['Recall'])
        results['f1_score'].append(metrics['F1_Score'])
        results['training_time'].append(train_time)
        results['time_complexity_ms'].append(T_com)
        results['space_complexity_mb'].append(S_com)
        results.setdefault('prediction_time', []).append(prediction_time)
        results.setdefault('history', []).append(history.history)
        print(f"REF_COUNT used          : {ref_count}")
        print(f"Train time (s)          : {train_time:.2f}")
        print(f"ADA / Acc / Prec / Rec / F1 (%): "
              f"{metrics['ADA']:.2f} / {metrics['Accuracy']:.2f} / {metrics['Precision']:.2f} / "
              f"{metrics['Recall']:.2f} / {metrics['F1_Score']:.2f}")
        print(f"T_com (ms)              : {T_com:.2f}")
        print(f"S_com (MB)              : {S_com:.2f}")
        del model
        tf.keras.backend.clear_session()

    return results
def display_results_table(results):
    print("\n" + "="*120)
    print("EXPERIMENT RESULTS WITH FIXED REF_COUNT (10) AND BROADCAST")
    print("="*120)
    print(f"{'Instances':<10} {'REF_COUNT':<10} {'ADA (%)':<8} {'Acc (%)':<8} {'Prec (%)':<9} "
          f"{'Rec (%)':<8} {'F1 (%)':<8} {'Train(s)':<9} {'T_com(ms)':<10} {'S_com(MB)':<10}")
    print("-"*120)
    for i in range(len(results['instances'])):
        print(f"{results['instances'][i]:<10} "
              f"{results['ref_count_used'][i]:<10} "
              f"{results['ADA'][i]:<8.2f} "
              f"{results['accuracy'][i]:<8.2f} "
              f"{results['precision'][i]:<9.2f} "
              f"{results['recall'][i]:<8.2f} "
              f"{results['f1_score'][i]:<8.2f} "
              f"{results['training_time'][i]:<9.2f} "
              f"{results['time_complexity_ms'][i]:<10.2f} "
              f"{results['space_complexity_mb'][i]:<10.2f}"
              f"{results['prediction_time'][i]:<10.2f}")

# %%
print(X.shape, y.shape, X.dtype, y.dtype)
# Out:
# (125973, 25) (125973,) float64 int64

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

def ensure_3d_X(X):
    X = np.asarray(X)
    if X.ndim == 2:   # (N, F) -> (N, F, 1)
        X = X.astype(np.float32)[..., np.newaxis]
    elif X.ndim == 3:
        X = X.astype(np.float32)
    else:
        raise ValueError(f"X harus 2D/3D. Dapat: {X.shape}")
    return X

def ensure_y_shape(y):
    y = np.asarray(y)
    if y.dtype == object:
        le = LabelEncoder()
        y = le.fit_transform(y)

    if not np.issubdtype(y.dtype, np.integer):
        y = y.astype(int)

    classes = np.unique(y)
    if len(classes) == 2 and set(classes) <= {0,1}:

        y = y.reshape(-1, 1).astype(np.float32)
    else:

        y = to_categorical(y.astype(int)).astype(np.float32)
    return y
X = ensure_3d_X(X)
y = ensure_y_shape(y)

print("After fix:", X.shape, X.dtype, "|", y.shape, y.dtype)
print("Unique y classes:", (int(y.shape[1]) if y.ndim==2 else 1), "class(es)")
instance_numbers = [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
instance_numbers = [n for n in instance_numbers if n <= X.shape[0]]

results = run_experiments_with_fixed_ref(
    X, y,
    instance_numbers=instance_numbers,
    ref_count_fixed=10,
    epochs=10,
    batch_size=128
)
# Out:
# After fix: (125973, 25, 1) float32 | (125973, 1) float32
# Unique y classes: 1 class(es)
#
# ======================================================================
# Running experiment with N = 10000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - accuracy: 0.5150 - loss: 1.0773 - val_accuracy: 0.5290 - val_loss: 0.6269
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5531 - loss: 0.6148 - val_accuracy: 0.8690 - val_loss: 0.5403
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8725 - loss: 0.5798 - val_accuracy: 0.9075 - val_loss: 0.5143
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9001 - loss: 0.5268 - val_accuracy: 0.9000 - val_loss: 0.4278
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8949 - loss: 0.4608 - val_accuracy: 0.8260 - val_loss: 0.5163
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8884 - loss: 0.4441 - val_accuracy: 0.8995 - val_loss: 0.3594
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8969 - loss: 0.4076 - val_accuracy: 0.8850 - val_loss: 0.3722
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8907 - loss: 0.3906 - val_accuracy: 0.8925 - val_loss: 0.3246
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8942 - loss: 0.3589 - val_accuracy: 0.8945 - val_loss: 0.3081
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8954 - loss: 0.3535 - val_accuracy: 0.8925 - val_loss: 0.3093
# REF_COUNT used          : 10
# Train time (s)          : 16.97
# ADA / Acc / Prec / Rec / F1 (%): 89.25 / 89.25 / 85.53 / 92.89 / 89.06
# T_com (ms)              : 752574.44
# S_com (MB)              : 0.99
#
# ======================================================================
# Running experiment with N = 20000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.5818 - loss: 0.7303 - val_accuracy: 0.8785 - val_loss: 0.5617
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8423 - loss: 0.5064 - val_accuracy: 0.9090 - val_loss: 0.4468
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8965 - loss: 0.3947 - val_accuracy: 0.9137 - val_loss: 0.3287
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9061 - loss: 0.3065 - val_accuracy: 0.9122 - val_loss: 0.2637
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9084 - loss: 0.2583 - val_accuracy: 0.9208 - val_loss: 0.2301
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9133 - loss: 0.2490 - val_accuracy: 0.9168 - val_loss: 0.2190
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9140 - loss: 0.2295 - val_accuracy: 0.9250 - val_loss: 0.2085
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9172 - loss: 0.2194 - val_accuracy: 0.9245 - val_loss: 0.2010
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9206 - loss: 0.2124 - val_accuracy: 0.9295 - val_loss: 0.1949
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9231 - loss: 0.2081 - val_accuracy: 0.9327 - val_loss: 0.1889
# REF_COUNT used          : 10
# Train time (s)          : 16.70
# ADA / Acc / Prec / Rec / F1 (%): 93.27 / 93.27 / 91.46 / 94.36 / 92.89
# T_com (ms)              : 1490178.11
# S_com (MB)              : 1.98
#
# ======================================================================
# Running experiment with N = 30000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.6759 - loss: 0.7020 - val_accuracy: 0.8915 - val_loss: 0.5314
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8952 - loss: 0.4139 - val_accuracy: 0.9095 - val_loss: 0.3245
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9037 - loss: 0.2945 - val_accuracy: 0.9075 - val_loss: 0.3686
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9144 - loss: 0.2466 - val_accuracy: 0.9285 - val_loss: 0.2372
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9201 - loss: 0.2317 - val_accuracy: 0.9198 - val_loss: 0.2300
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9233 - loss: 0.2185 - val_accuracy: 0.9188 - val_loss: 0.2144
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9251 - loss: 0.2263 - val_accuracy: 0.9278 - val_loss: 0.2039
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9307 - loss: 0.1953 - val_accuracy: 0.9363 - val_loss: 0.1808
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9369 - loss: 0.1781 - val_accuracy: 0.9315 - val_loss: 0.1758
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9419 - loss: 0.1654 - val_accuracy: 0.9395 - val_loss: 0.1655
# REF_COUNT used          : 10
# Train time (s)          : 24.15
# ADA / Acc / Prec / Rec / F1 (%): 93.95 / 93.95 / 91.84 / 95.54 / 93.65
# T_com (ms)              : 2359089.37
# S_com (MB)              : 2.98
#
# ======================================================================
# Running experiment with N = 40000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8502 - loss: 0.4672 - val_accuracy: 0.9150 - val_loss: 0.3337
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9143 - loss: 0.2966 - val_accuracy: 0.9144 - val_loss: 0.2472
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9174 - loss: 0.2275 - val_accuracy: 0.9193 - val_loss: 0.2194
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9248 - loss: 0.2110 - val_accuracy: 0.9273 - val_loss: 0.2024
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9303 - loss: 0.1986 - val_accuracy: 0.9311 - val_loss: 0.1948
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9327 - loss: 0.1920 - val_accuracy: 0.9300 - val_loss: 0.1892
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9361 - loss: 0.1832 - val_accuracy: 0.9359 - val_loss: 0.1784
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9396 - loss: 0.1723 - val_accuracy: 0.9350 - val_loss: 0.1704
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9438 - loss: 0.1643 - val_accuracy: 0.9429 - val_loss: 0.1558
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9465 - loss: 0.1543 - val_accuracy: 0.9476 - val_loss: 0.1680
# REF_COUNT used          : 10
# Train time (s)          : 25.60
# ADA / Acc / Prec / Rec / F1 (%): 94.76 / 94.76 / 96.51 / 92.15 / 94.28
# T_com (ms)              : 3054540.63
# S_com (MB)              : 3.97
#
# ======================================================================
# Running experiment with N = 50000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.8425 - loss: 0.4319 - val_accuracy: 0.9131 - val_loss: 0.2714
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9161 - loss: 0.2580 - val_accuracy: 0.9316 - val_loss: 0.2203
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9281 - loss: 0.2204 - val_accuracy: 0.9349 - val_loss: 0.2077
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9360 - loss: 0.1969 - val_accuracy: 0.9436 - val_loss: 0.1713
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9430 - loss: 0.1781 - val_accuracy: 0.9444 - val_loss: 0.1660
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9447 - loss: 0.1714 - val_accuracy: 0.9477 - val_loss: 0.1754
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9472 - loss: 0.1626 - val_accuracy: 0.9523 - val_loss: 0.1515
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9486 - loss: 0.1585 - val_accuracy: 0.9510 - val_loss: 0.1587
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9513 - loss: 0.1493 - val_accuracy: 0.9500 - val_loss: 0.1431
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9532 - loss: 0.1423 - val_accuracy: 0.9502 - val_loss: 0.1431
# REF_COUNT used          : 10
# Train time (s)          : 32.98
# ADA / Acc / Prec / Rec / F1 (%): 95.02 / 95.02 / 93.87 / 95.63 / 94.74
# T_com (ms)              : 3768730.16
# S_com (MB)              : 4.96
#
# ======================================================================
# Running experiment with N = 60000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8723 - loss: 0.4354 - val_accuracy: 0.8925 - val_loss: 0.4283
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8881 - loss: 0.3563 - val_accuracy: 0.8960 - val_loss: 0.3420
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8978 - loss: 0.3263 - val_accuracy: 0.8351 - val_loss: 0.4013
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8988 - loss: 0.3067 - val_accuracy: 0.9010 - val_loss: 0.2847
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9127 - loss: 0.2912 - val_accuracy: 0.9239 - val_loss: 0.2572
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9147 - loss: 0.2813 - val_accuracy: 0.9358 - val_loss: 0.2674
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9233 - loss: 0.2658 - val_accuracy: 0.9416 - val_loss: 0.2344
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9301 - loss: 0.2575 - val_accuracy: 0.9438 - val_loss: 0.2176
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9351 - loss: 0.2403 - val_accuracy: 0.9477 - val_loss: 0.2087
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9421 - loss: 0.2362 - val_accuracy: 0.9504 - val_loss: 0.2506
# REF_COUNT used          : 10
# Train time (s)          : 34.64
# ADA / Acc / Prec / Rec / F1 (%): 95.04 / 95.04 / 94.22 / 95.25 / 94.73
# T_com (ms)              : 4668737.41
# S_com (MB)              : 5.95
#
# ======================================================================
# Running experiment with N = 70000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7749 - loss: 0.5623 - val_accuracy: 0.9154 - val_loss: 0.3255
# Epoch 2/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8915 - loss: 0.3443 - val_accuracy: 0.9213 - val_loss: 0.2421
# Epoch 3/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8988 - loss: 0.2962 - val_accuracy: 0.8476 - val_loss: 0.4918
# Epoch 4/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8875 - loss: 0.3464 - val_accuracy: 0.9239 - val_loss: 0.2386
# Epoch 5/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9072 - loss: 0.3076 - val_accuracy: 0.9193 - val_loss: 0.2651
# Epoch 6/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9159 - loss: 0.2822 - val_accuracy: 0.9209 - val_loss: 0.2753
# Epoch 7/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9199 - loss: 0.2729 - val_accuracy: 0.9384 - val_loss: 0.2229
# Epoch 8/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9269 - loss: 0.2408 - val_accuracy: 0.9374 - val_loss: 0.1960
# Epoch 9/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9311 - loss: 0.2334 - val_accuracy: 0.9403 - val_loss: 0.1898
# Epoch 10/10
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9386 - loss: 0.2087 - val_accuracy: 0.9179 - val_loss: 0.2325
# REF_COUNT used          : 10
# Train time (s)          : 42.01
# ADA / Acc / Prec / Rec / F1 (%): 91.79 / 91.79 / 87.83 / 95.71 / 91.60
# T_com (ms)              : 5557890.89
# S_com (MB)              : 6.94
#
# ======================================================================
# Running experiment with N = 80000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8503 - loss: 0.4629 - val_accuracy: 0.8926 - val_loss: 0.2963
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9085 - loss: 0.2494 - val_accuracy: 0.9195 - val_loss: 0.2226
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9263 - loss: 0.2091 - val_accuracy: 0.9331 - val_loss: 0.1919
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9364 - loss: 0.1796 - val_accuracy: 0.9439 - val_loss: 0.1619
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9452 - loss: 0.1508 - val_accuracy: 0.9506 - val_loss: 0.1354
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9515 - loss: 0.1310 - val_accuracy: 0.9549 - val_loss: 0.1269
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9535 - loss: 0.1218 - val_accuracy: 0.9575 - val_loss: 0.1123
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9560 - loss: 0.1142 - val_accuracy: 0.9571 - val_loss: 0.1063
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9582 - loss: 0.1073 - val_accuracy: 0.9597 - val_loss: 0.1051
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9613 - loss: 0.1032 - val_accuracy: 0.9675 - val_loss: 0.0971
# REF_COUNT used          : 10
# Train time (s)          : 42.60
# ADA / Acc / Prec / Rec / F1 (%): 96.75 / 96.75 / 97.45 / 95.54 / 96.48
# T_com (ms)              : 6145816.80
# S_com (MB)              : 7.94
#
# ======================================================================
# Running experiment with N = 90000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step - accuracy: 0.8429 - loss: 0.4632 - val_accuracy: 0.8922 - val_loss: 0.3010
# Epoch 2/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8831 - loss: 0.3271 - val_accuracy: 0.9182 - val_loss: 0.2524
# Epoch 3/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8916 - loss: 0.3037 - val_accuracy: 0.9142 - val_loss: 0.2392
# Epoch 4/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8929 - loss: 0.3020 - val_accuracy: 0.9129 - val_loss: 0.2290
# Epoch 5/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8951 - loss: 0.2935 - val_accuracy: 0.9173 - val_loss: 0.2230
# Epoch 6/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9066 - loss: 0.2742 - val_accuracy: 0.9183 - val_loss: 0.2170
# Epoch 7/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9068 - loss: 0.2608 - val_accuracy: 0.9345 - val_loss: 0.2078
# Epoch 8/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9140 - loss: 0.2587 - val_accuracy: 0.9154 - val_loss: 0.2199
# Epoch 9/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9131 - loss: 0.2612 - val_accuracy: 0.8910 - val_loss: 0.2440
# Epoch 10/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9244 - loss: 0.2469 - val_accuracy: 0.9162 - val_loss: 0.2185
# REF_COUNT used          : 10
# Train time (s)          : 50.60
# ADA / Acc / Prec / Rec / F1 (%): 91.62 / 91.62 / 87.37 / 95.86 / 91.42
# T_com (ms)              : 7072637.56
# S_com (MB)              : 8.93
#
# ======================================================================
# Running experiment with N = 100000 (REF_COUNT fixed = 10)
# ======================================================================
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.8421 - loss: 0.4903 - val_accuracy: 0.8762 - val_loss: 0.3189
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8913 - loss: 0.3261 - val_accuracy: 0.4656 - val_loss: 1.2975
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8854 - loss: 0.3053 - val_accuracy: 0.9053 - val_loss: 0.2402
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9191 - loss: 0.2129 - val_accuracy: 0.9352 - val_loss: 0.1726
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9413 - loss: 0.1569 - val_accuracy: 0.9459 - val_loss: 0.1501
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9493 - loss: 0.1382 - val_accuracy: 0.9510 - val_loss: 0.1337
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9519 - loss: 0.1300 - val_accuracy: 0.9503 - val_loss: 0.1280
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9542 - loss: 0.1233 - val_accuracy: 0.9567 - val_loss: 0.1176
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9555 - loss: 0.1186 - val_accuracy: 0.9577 - val_loss: 0.1202
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9568 - loss: 0.1121 - val_accuracy: 0.9616 - val_loss: 0.1061
# REF_COUNT used          : 10
# Train time (s)          : 52.18
# ADA / Acc / Prec / Rec / F1 (%): 96.16 / 96.16 / 96.62 / 95.08 / 95.84
# T_com (ms)              : 7745771.41
# S_com (MB)              : 9.92

# %%
display_results_table(results)
# Out:
# ========================================================================================================================
# EXPERIMENT RESULTS WITH FIXED REF_COUNT (10) AND BROADCAST
# ========================================================================================================================
# Instances  REF_COUNT  ADA (%)  Acc (%)  Prec (%)  Rec (%)  F1 (%)   Train(s)  T_com(ms)  S_com(MB)
# ------------------------------------------------------------------------------------------------------------------------
# 10000      10         89.25    89.25    85.53     92.89    89.06    16.97     752574.44  0.99      2.59
# 20000      10         93.27    93.27    91.46     94.36    92.89    16.70     1490178.11 1.98      1.37
# 30000      10         93.95    93.95    91.84     95.54    93.65    24.15     2359089.37 2.98      2.67
# 40000      10         94.76    94.76    96.51     92.15    94.28    25.60     3054540.63 3.97      1.70
# 50000      10         95.02    95.02    93.87     95.63    94.74    32.98     3768730.16 4.96      3.01
# 60000      10         95.04    95.04    94.22     95.25    94.73    34.64     4668737.41 5.95      1.98
# 70000      10         91.79    91.79    87.83     95.71    91.60    42.01     5557890.89 6.94      3.17
# 80000      10         96.75    96.75    97.45     95.54    96.48    42.60     6145816.80 7.94      2.24
# 90000      10         91.62    91.62    87.37     95.86    91.42    50.60     7072637.56 8.93      3.46
# 100000     10         96.16    96.16    96.62     95.08    95.84    52.18     7745771.41 9.92      2.49

# %%
import matplotlib.pyplot as plt

for i, hist in enumerate(results['history']):
    n = results['instances'][i]

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(hist['accuracy'], label='Train Accuracy')
    axes[0].plot(hist['val_accuracy'], label='Val Accuracy')
    axes[0].set_title(f'Accuracy - {n//1000}k instances')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(False)

    axes[1].plot(hist['loss'], label='Train Loss')
    axes[1].plot(hist['val_loss'], label='Val Loss')
    axes[1].set_title(f'Loss - {n//1000}k instances')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(False)

    plt.tight_layout()
    plt.show()
