# %%
import pandas as pd
import numpy as np
from scipy.io import arff
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import numpy as np
import time
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, TimeDistributed, Lambda
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score, confusion_matrix

# %%
path = '.../KDDTrain+.arff'
data, meta = arff.loadarff(path)
df = pd.DataFrame(data)
for col in df.select_dtypes([object]):
    df[col] = df[col].str.decode('utf-8')
df['label'] = (df[df.columns[-1]] != 'normal').astype(int)

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing (%)': missing_pct.round(2)
})

missing_cols = missing_df[missing_df['Missing Count'] > 0]

if missing_cols.empty:
    print("No missing values found.")
else:
    print(f"Missing values found in {len(missing_cols)} column(s):\n")
    print(missing_cols.to_string())

print(f"Total rows       : {len(df)}")
print(f"Total columns    : {df.shape[1]}")
print(f"Total missing    : {df.isnull().sum().sum()}")
print(f"Affected columns : {len(missing_cols)}")
# Out:
# No missing values found.
# Total rows       : 125973
# Total columns    : 43
# Total missing    : 0
# Affected columns : 0

# %%
selected_features = [
    'num_access_files',
    'dst_bytes',
    'dst_host_count',
    'num_compromised',
    'dst_host_same_srv_rate',
    'same_srv_rate',
    'dst_host_srv_count',
    'serror_rate',
    'count',
    'rerror_rate',
    'dst_host_srv_rerror_rate',
    'dst_host_srv_serror_rate',
    'dst_host_rerror_rate',
    'dst_host_same_src_port_rate',
    'dst_host_serror_rate',
    'num_file_creations',
    'srv_count',
    'srv_serror_rate',
    'srv_rerror_rate',
    'srv_diff_host_rate',
    'wrong_fragment',
    'urgent',
    'src_bytes',
    'hot',
    'num_failed_logins'
]

print(f"Total features: {len(selected_features)}")
# Out:
# Total features: 25

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# %%
X = df[selected_features].values
y = df.iloc[:, 42].values

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# JaspenCorrelation Layer

class JaspenCorrelation(tf.keras.layers.Layer):
    def call(self, inputs):
        t, r = inputs  # t: (None, feat_dim), r: (None, REF_COUNT, feat_dim)
        t_exp = tf.expand_dims(t, 1)              # (None, 1, feat_dim)
        dot = tf.reduce_sum(t_exp * r, axis=2)    # (None, REF_COUNT)

        sum_t = tf.reduce_sum(t_exp, axis=2)      # (None, 1)
        sum_r = tf.reduce_sum(r, axis=2)          # (None, REF_COUNT)

        n = tf.cast(tf.shape(t)[1], tf.float32)
        corr = (n * dot - sum_t * sum_r) / (tf.sqrt(n * sum_t) * tf.sqrt(n * sum_r) + 1e-8)
        return tf.maximum(corr, 0.0)              # only positive correlation

# Model with fixed REF_COUNT input
def create_model(ref_count, seq_len, channels, num_classes, is_multiclass):
    test_input = Input(shape=(seq_len, channels), name="test_input")
    reference_input = Input(shape=(ref_count, seq_len, channels), name="reference_input")

    shared_cnn = tf.keras.Sequential([
        Conv1D(64, 3, activation='relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, activation='relu'),
        MaxPooling1D(2),
        Flatten()
    ], name='shared_cnn')

    test_encoded = shared_cnn(test_input)                     # (None, feat_dim)
    reference_encoded = TimeDistributed(shared_cnn)(reference_input)  # (None, REF_COUNT, feat_dim)

    corr = JaspenCorrelation()([test_encoded, reference_encoded])     # (None, REF_COUNT)
    agg = Lambda(lambda x: tf.reduce_mean(x, axis=1, keepdims=True))(corr)  # (None, 1)

    x = Dense(128, activation='relu')(agg)

    if is_multiclass:
        output = Dense(num_classes, activation='softmax')(x)
        loss = 'categorical_crossentropy'
    else:
        output = Dense(num_classes, activation='sigmoid')(x)
        loss = 'binary_crossentropy'

    model = Model(inputs=[test_input, reference_input], outputs=output)
    return model, loss

# %%
def calculate_all_metrics(y_true, y_pred, is_multiclass, threshold=0.5):
    if is_multiclass:
        y_true_cls = np.argmax(y_true, axis=1)
        y_pred_cls = np.argmax(y_pred, axis=1)
        acc = accuracy_score(y_true_cls, y_pred_cls)
        prec = precision_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        rec = recall_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
        f1 = f1_score(y_true_cls, y_pred_cls, average='macro', zero_division=0)
    else:
        y_pred_bin = (y_pred >= threshold).astype(int)
        average = 'binary' if y_true.shape[1] == 1 else 'macro'
        acc = accuracy_score(y_true, y_pred_bin)
        prec = precision_score(y_true, y_pred_bin, average=average, zero_division=0)
        rec = recall_score(y_true, y_pred_bin, average=average, zero_division=0)
        f1 = f1_score(y_true, y_pred_bin, average=average, zero_division=0)

    return {
        'ADA': acc * 100.0,
        'Accuracy': acc * 100.0,
        'Precision': prec * 100.0,
        'Recall': rec * 100.0,
        'F1_Score': f1 * 100.0
    }

# %%
#Space & time complexity
def calculate_space_per_instance_broadcast(X_sample, y_sample):
    return (X_sample.nbytes + y_sample.nbytes) / (1024 * 1024)
def reference_set_size_mb(reference_set):
    return reference_set.nbytes / (1024 * 1024)
def measure_single_instance_time(model, X_sample, reference_set, num_trials=5):
    ref_input = np.broadcast_to(reference_set[np.newaxis, ...],
                                (1,) + reference_set.shape)
    _ = model.predict([X_sample, ref_input], verbose=0)
    times = []
    for _ in range(num_trials):
        t0 = time.time()
        _ = model.predict([X_sample, ref_input], verbose=0)
        times.append((time.time() - t0) * 1000.0)
    return float(np.mean(times))

# %%
# Main experiment loop
def run_experiments_with_fixed_ref(X, y, instance_numbers=None, ref_count_fixed=20,
                                   epochs=10, batch_size=16, test_size=0.2, random_state=42):
    assert X.shape[0] == y.shape[0], "X and y must have the same number of samples"
    N, SEQ_LEN, CHANNELS = X.shape[0], X.shape[1], X.shape[2]
    NUM_CLASSES = y.shape[1]
    is_multiclass = (NUM_CLASSES > 1) and (np.all((y == 0) | (y == 1)) and np.all(y.sum(axis=1) == 1))

    # default instance_numbers
    if instance_numbers is None:
        instance_numbers = [10000, 20000, 30000, 40000, 50000,
                            60000, 70000, 80000, 90000, 100000]

    results = {
        'instances': [],
        'ref_count_used': [],
        'accuracy': [],
        'ADA':[],
        'precision': [],
        'recall': [],
        'f1_score': [],
        'training_time': [],
        'time_complexity_ms': [],
        'space_complexity_mb': []
    }
    X = X.astype(np.float32)
    y = y.astype(np.float32)

    for n_instances in instance_numbers:
        if n_instances > N:
            print(f"Skip N={n_instances}: not enough data (dataset size={N})")
            continue

        print("\n" + "="*70)
        print(f"Running experiment with N = {n_instances} (Number of Samples = {ref_count_fixed})")
        print("="*70)

        X_sub = X[:n_instances]
        y_sub = y[:n_instances]

        if is_multiclass:
            y_strat = np.argmax(y_sub, axis=1)
        else:
            y_strat = y_sub.squeeze()
            if y_sub.ndim == 2 and y_sub.shape[1] > 1:
                y_strat = None

        X_train_subset, X_test_subset, y_train_subset, y_test_subset = train_test_split(
            X_sub, y_sub, test_size=test_size, stratify=y_strat, random_state=random_state
        )

        ref_count = min(ref_count_fixed, len(X_train_subset))
        reference_set = X_train_subset[:ref_count]
        reference_input_train_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_train_subset.shape[0],) + reference_set.shape
        )
        reference_input_test_subset = np.broadcast_to(
            reference_set[np.newaxis, ...],
            (X_test_subset.shape[0],) + reference_set.shape
        )

        # compile model
        model, loss = create_model(ref_count, SEQ_LEN, CHANNELS, NUM_CLASSES, is_multiclass)
        model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])

        # space complexity
        X_sample = X_train_subset[0:1]
        y_sample = y_train_subset[0:1]

        space_per_instance = calculate_space_per_instance_broadcast(X_sample, y_sample)
        # total space
        S_com = n_instances * space_per_instance + reference_set_size_mb(reference_set)

       # Train
        t0 = time.time()
        history = model.fit(
            [X_train_subset, reference_input_train_subset],
            y_train_subset,
            validation_data=([X_test_subset, reference_input_test_subset], y_test_subset),
            epochs=epochs,
            batch_size=batch_size,
            verbose=1
        )
        train_time = time.time() - t0


        #Predict & metrics with timing
        pred_start = time.time()
        y_pred = model.predict([X_test_subset, reference_input_test_subset], verbose=0)
        metrics = calculate_all_metrics(y_test_subset, y_pred, is_multiclass)
        pred_end = time.time()
        prediction_time = pred_end - pred_start

        #Time per instance (inference) & T_com
        tpi = measure_single_instance_time(model, X_sample, reference_set, num_trials=5)
        T_com = n_instances * tpi

        results['instances'].append(n_instances)
        results['ref_count_used'].append(ref_count)
        results['ADA'].append(metrics['ADA'])
        results['accuracy'].append(metrics['Accuracy'])
        results['precision'].append(metrics['Precision'])
        results['recall'].append(metrics['Recall'])
        results['f1_score'].append(metrics['F1_Score'])
        results['training_time'].append(train_time)
        results['time_complexity_ms'].append(T_com)
        results['space_complexity_mb'].append(S_com)
        results.setdefault('prediction_time', []).append(prediction_time)
        results.setdefault('history', []).append(history.history)  # TAMBAHKAN INI

        print(f"REF_COUNT used          : {ref_count}")
        print(f"Train time (s)          : {train_time:.2f}")
        print(f"Acc / Prec / Rec / F1 (%): "
              f" {metrics['Accuracy']:.2f} / {metrics['Precision']:.2f} / "
              f"{metrics['Recall']:.2f} / {metrics['F1_Score']:.2f}")
        print(f"T_com (ms)              : {T_com:.2f}")
        print(f"S_com (MB)              : {S_com:.2f}")

        del model
        tf.keras.backend.clear_session()

    return results

# %%
# Display Result
def display_results_table(results):
    print("\n" + "="*120)
    print("Experiment Results With Number of Samples (20)")
    print("="*120)
    print(f"{'Instances':<10} {'Number of Samples':<10} {'Acc (%)':<8} {'Prec (%)':<9} "
          f"{'Rec (%)':<8} {'F1 (%)':<8} {'Train(s)':<9} {'T_com(ms)':<10} {'S_com(MB)':<10}")
    print("-"*120)
    for i in range(len(results['instances'])):
        print(f"{results['instances'][i]:<10} "
              f"{results['ref_count_used'][i]:<10} "
              f"{results['ADA'][i]:<8.2f} "
              f"{results['accuracy'][i]:<8.2f} "
              f"{results['precision'][i]:<9.2f} "
              f"{results['recall'][i]:<8.2f} "
              f"{results['f1_score'][i]:<8.2f} "
              f"{results['training_time'][i]:<9.2f} "
              f"{results['time_complexity_ms'][i]:<10.2f} "
              f"{results['space_complexity_mb'][i]:<10.2f}"
              f"{results['prediction_time'][i]:<10.2f}")

# %%
print(X.shape, y.shape, X.dtype, y.dtype)
# Out:
# (125973, 25) (125973,) float64 int64

# %%
def ensure_3d_X(X):
    X = np.asarray(X)
    if X.ndim == 2:   # (N, F) -> (N, F, 1)
        X = X.astype(np.float32)[..., np.newaxis]
    elif X.ndim == 3:
        X = X.astype(np.float32)
    else:
        raise ValueError(f"X must to be 2D/3D. Get: {X.shape}")
    return X

def ensure_y_shape(y):
    y = np.asarray(y)
    if y.dtype == object:
        le = LabelEncoder()
        y = le.fit_transform(y)
    if not np.issubdtype(y.dtype, np.integer):
        y = y.astype(int)
    classes = np.unique(y)
    if len(classes) == 2 and set(classes) <= {0,1}:
        y = y.reshape(-1, 1).astype(np.float32)
    else:
        y = to_categorical(y.astype(int)).astype(np.float32)
    return y

X = ensure_3d_X(X)   # (125973, 18) -> (125973, 18, 1)
y = ensure_y_shape(y)

print("After fix:", X.shape, X.dtype, "|", y.shape, y.dtype)
print("Unique y classes:", (int(y.shape[1]) if y.ndim==2 else 1), "class(es)")

# Intance numbers
instance_numbers = [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
instance_numbers = [n for n in instance_numbers if n <= X.shape[0]]

results = run_experiments_with_fixed_ref(
    X, y,
    instance_numbers=instance_numbers,
    ref_count_fixed=20,
    epochs=10,
    batch_size=16
)
# Out:
# After fix: (125973, 25, 1) float32 | (125973, 1) float32
# Unique y classes: 1 class(es)
#
# ======================================================================
# Running experiment with N = 10000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.8094 - loss: 0.6299 - val_accuracy: 0.8775 - val_loss: 0.4719
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8861 - loss: 0.3918 - val_accuracy: 0.8865 - val_loss: 0.3146
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8910 - loss: 0.3457 - val_accuracy: 0.8850 - val_loss: 0.3049
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8919 - loss: 0.2828 - val_accuracy: 0.8925 - val_loss: 0.2791
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8971 - loss: 0.2647 - val_accuracy: 0.8960 - val_loss: 0.2615
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9057 - loss: 0.2467 - val_accuracy: 0.9060 - val_loss: 0.2523
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9122 - loss: 0.2304 - val_accuracy: 0.9130 - val_loss: 0.2413
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8971 - loss: 0.3717 - val_accuracy: 0.9005 - val_loss: 0.2553
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9140 - loss: 0.2306 - val_accuracy: 0.8960 - val_loss: 0.2644
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9096 - loss: 0.2873 - val_accuracy: 0.9010 - val_loss: 0.2529
# REF_COUNT used          : 20
# Train time (s)          : 34.43
# Acc / Prec / Rec / F1 (%):  90.10 / 85.98 / 94.37 / 89.98
# T_com (ms)              : 707123.28
# S_com (MB)              : 0.99
#
# ======================================================================
# Running experiment with N = 20000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8570 - loss: 0.4076 - val_accuracy: 0.9212 - val_loss: 0.2980
# Epoch 2/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9101 - loss: 0.2391 - val_accuracy: 0.9235 - val_loss: 0.2078
# Epoch 3/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9162 - loss: 0.2244 - val_accuracy: 0.9283 - val_loss: 0.1965
# Epoch 4/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9202 - loss: 0.2176 - val_accuracy: 0.9358 - val_loss: 0.1917
# Epoch 5/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9213 - loss: 0.2231 - val_accuracy: 0.9340 - val_loss: 0.1863
# Epoch 6/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9240 - loss: 0.2035 - val_accuracy: 0.9362 - val_loss: 0.1872
# Epoch 7/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9271 - loss: 0.1973 - val_accuracy: 0.9388 - val_loss: 0.1748
# Epoch 8/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9300 - loss: 0.1954 - val_accuracy: 0.9362 - val_loss: 0.1810
# Epoch 9/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9311 - loss: 0.1903 - val_accuracy: 0.9383 - val_loss: 0.1710
# Epoch 10/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9336 - loss: 0.1869 - val_accuracy: 0.9375 - val_loss: 0.1742
# REF_COUNT used          : 20
# Train time (s)          : 56.95
# Acc / Prec / Rec / F1 (%):  93.75 / 90.25 / 97.04 / 93.53
# T_com (ms)              : 1551582.34
# S_com (MB)              : 1.99
#
# ======================================================================
# Running experiment with N = 30000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.8570 - loss: 0.3682 - val_accuracy: 0.9198 - val_loss: 0.2223
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9228 - loss: 0.2162 - val_accuracy: 0.9323 - val_loss: 0.1944
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9340 - loss: 0.1926 - val_accuracy: 0.9400 - val_loss: 0.1734
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9415 - loss: 0.1704 - val_accuracy: 0.9442 - val_loss: 0.1545
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9477 - loss: 0.1540 - val_accuracy: 0.9498 - val_loss: 0.1405
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9475 - loss: 0.1430 - val_accuracy: 0.9465 - val_loss: 0.1433
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9490 - loss: 0.1374 - val_accuracy: 0.9467 - val_loss: 0.1260
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9515 - loss: 0.1293 - val_accuracy: 0.9482 - val_loss: 0.1335
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9514 - loss: 0.1254 - val_accuracy: 0.9550 - val_loss: 0.1155
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9528 - loss: 0.1223 - val_accuracy: 0.9542 - val_loss: 0.1196
# REF_COUNT used          : 20
# Train time (s)          : 80.85
# Acc / Prec / Rec / F1 (%):  95.42 / 96.00 / 94.11 / 95.04
# T_com (ms)              : 2233988.29
# S_com (MB)              : 2.98
#
# ======================================================================
# Running experiment with N = 40000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.8748 - loss: 0.3091 - val_accuracy: 0.9184 - val_loss: 0.2011
# Epoch 2/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9328 - loss: 0.1857 - val_accuracy: 0.9356 - val_loss: 0.1848
# Epoch 3/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9455 - loss: 0.1597 - val_accuracy: 0.9451 - val_loss: 0.1538
# Epoch 4/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9481 - loss: 0.1505 - val_accuracy: 0.9554 - val_loss: 0.1366
# Epoch 5/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9539 - loss: 0.1335 - val_accuracy: 0.9590 - val_loss: 0.1255
# Epoch 6/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9568 - loss: 0.1295 - val_accuracy: 0.9486 - val_loss: 0.1519
# Epoch 7/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9584 - loss: 0.1308 - val_accuracy: 0.9510 - val_loss: 0.1465
# Epoch 8/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9596 - loss: 0.1224 - val_accuracy: 0.9626 - val_loss: 0.1166
# Epoch 9/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9599 - loss: 0.1207 - val_accuracy: 0.9629 - val_loss: 0.1163
# Epoch 10/10
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9610 - loss: 0.1190 - val_accuracy: 0.9631 - val_loss: 0.1141
# REF_COUNT used          : 20
# Train time (s)          : 104.04
# Acc / Prec / Rec / F1 (%):  96.31 / 97.55 / 94.50 / 96.00
# T_com (ms)              : 2885450.36
# S_com (MB)              : 3.97
#
# ======================================================================
# Running experiment with N = 50000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.8302 - loss: 0.4271 - val_accuracy: 0.7481 - val_loss: 0.4240
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8492 - loss: 0.3609 - val_accuracy: 0.9102 - val_loss: 0.2616
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9173 - loss: 0.2533 - val_accuracy: 0.9265 - val_loss: 0.2065
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9267 - loss: 0.2251 - val_accuracy: 0.9413 - val_loss: 0.1804
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9392 - loss: 0.2034 - val_accuracy: 0.9421 - val_loss: 0.1689
# Epoch 6/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9431 - loss: 0.1761 - val_accuracy: 0.9438 - val_loss: 0.1740
# Epoch 7/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9335 - loss: 0.2597 - val_accuracy: 0.9536 - val_loss: 0.4611
# Epoch 8/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9370 - loss: 0.2394 - val_accuracy: 0.9406 - val_loss: 0.2136
# Epoch 9/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9305 - loss: 0.2352 - val_accuracy: 0.9464 - val_loss: 0.1908
# Epoch 10/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9425 - loss: 0.2057 - val_accuracy: 0.9459 - val_loss: 0.2437
# REF_COUNT used          : 20
# Train time (s)          : 127.38
# Acc / Prec / Rec / F1 (%):  94.59 / 96.17 / 92.13 / 94.11
# T_com (ms)              : 3650054.93
# S_com (MB)              : 4.96
#
# ======================================================================
# Running experiment with N = 60000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.8786 - loss: 0.3271 - val_accuracy: 0.9047 - val_loss: 0.2549
# Epoch 2/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9313 - loss: 0.2013 - val_accuracy: 0.9399 - val_loss: 0.1776
# Epoch 3/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9427 - loss: 0.1745 - val_accuracy: 0.9354 - val_loss: 0.1921
# Epoch 4/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9458 - loss: 0.1632 - val_accuracy: 0.9456 - val_loss: 0.1638
# Epoch 5/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9480 - loss: 0.1543 - val_accuracy: 0.9517 - val_loss: 0.1448
# Epoch 6/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9504 - loss: 0.1446 - val_accuracy: 0.9518 - val_loss: 0.1340
# Epoch 7/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9537 - loss: 0.1322 - val_accuracy: 0.9578 - val_loss: 0.1306
# Epoch 8/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9580 - loss: 0.1219 - val_accuracy: 0.9618 - val_loss: 0.1165
# Epoch 9/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9610 - loss: 0.1168 - val_accuracy: 0.9627 - val_loss: 0.1164
# Epoch 10/10
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9644 - loss: 0.1112 - val_accuracy: 0.9655 - val_loss: 0.1059
# REF_COUNT used          : 20
# Train time (s)          : 151.72
# Acc / Prec / Rec / F1 (%):  96.55 / 96.80 / 95.80 / 96.29
# T_com (ms)              : 4254438.40
# S_com (MB)              : 5.95
#
# ======================================================================
# Running experiment with N = 70000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.8855 - loss: 0.3326 - val_accuracy: 0.9274 - val_loss: 0.2553
# Epoch 2/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9172 - loss: 0.2724 - val_accuracy: 0.8919 - val_loss: 0.3832
# Epoch 3/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9369 - loss: 0.1948 - val_accuracy: 0.9522 - val_loss: 0.1524
# Epoch 4/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9458 - loss: 0.1626 - val_accuracy: 0.9534 - val_loss: 0.1370
# Epoch 5/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9522 - loss: 0.1411 - val_accuracy: 0.9553 - val_loss: 0.1327
# Epoch 6/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9555 - loss: 0.1268 - val_accuracy: 0.9532 - val_loss: 0.1405
# Epoch 7/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9599 - loss: 0.1095 - val_accuracy: 0.9637 - val_loss: 0.0939
# Epoch 8/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9619 - loss: 0.0998 - val_accuracy: 0.9619 - val_loss: 0.1132
# Epoch 9/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9656 - loss: 0.0917 - val_accuracy: 0.9708 - val_loss: 0.0797
# Epoch 10/10
# 3500/3500 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.9690 - loss: 0.0845 - val_accuracy: 0.9736 - val_loss: 0.0715
# REF_COUNT used          : 20
# Train time (s)          : 174.36
# Acc / Prec / Rec / F1 (%):  97.36 / 98.22 / 96.09 / 97.15
# T_com (ms)              : 5077365.88
# S_com (MB)              : 6.94
#
# ======================================================================
# Running experiment with N = 80000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - accuracy: 0.9195 - loss: 0.2417 - val_accuracy: 0.9522 - val_loss: 0.1539
# Epoch 2/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9511 - loss: 0.1377 - val_accuracy: 0.9600 - val_loss: 0.1150
# Epoch 3/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9604 - loss: 0.1125 - val_accuracy: 0.9686 - val_loss: 0.0909
# Epoch 4/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9671 - loss: 0.0924 - val_accuracy: 0.9691 - val_loss: 0.0854
# Epoch 5/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9738 - loss: 0.0779 - val_accuracy: 0.9774 - val_loss: 0.0684
# Epoch 6/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9786 - loss: 0.0645 - val_accuracy: 0.9803 - val_loss: 0.0608
# Epoch 7/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9812 - loss: 0.0589 - val_accuracy: 0.9809 - val_loss: 0.0597
# Epoch 8/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9829 - loss: 0.0552 - val_accuracy: 0.9806 - val_loss: 0.0581
# Epoch 9/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9845 - loss: 0.0533 - val_accuracy: 0.9843 - val_loss: 0.0562
# Epoch 10/10
# 4000/4000 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9814 - loss: 0.0673 - val_accuracy: 0.9804 - val_loss: 0.0648
# REF_COUNT used          : 20
# Train time (s)          : 199.01
# Acc / Prec / Rec / F1 (%):  98.04 / 98.40 / 97.39 / 97.89
# T_com (ms)              : 5716564.18
# S_com (MB)              : 7.94
#
# ======================================================================
# Running experiment with N = 90000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - accuracy: 0.8896 - loss: 0.3255 - val_accuracy: 0.9114 - val_loss: 0.2337
# Epoch 2/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9302 - loss: 0.1849 - val_accuracy: 0.9482 - val_loss: 0.1531
# Epoch 3/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9515 - loss: 0.1339 - val_accuracy: 0.9519 - val_loss: 0.1341
# Epoch 4/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9578 - loss: 0.1184 - val_accuracy: 0.9582 - val_loss: 0.1146
# Epoch 5/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9602 - loss: 0.1111 - val_accuracy: 0.9612 - val_loss: 0.1059
# Epoch 6/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9617 - loss: 0.1077 - val_accuracy: 0.9620 - val_loss: 0.1063
# Epoch 7/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9633 - loss: 0.1047 - val_accuracy: 0.9599 - val_loss: 0.1093
# Epoch 8/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.9644 - loss: 0.1003 - val_accuracy: 0.9629 - val_loss: 0.1027
# Epoch 9/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.9671 - loss: 0.0935 - val_accuracy: 0.9679 - val_loss: 0.0907
# Epoch 10/10
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9688 - loss: 0.0904 - val_accuracy: 0.9679 - val_loss: 0.0979
# REF_COUNT used          : 20
# Train time (s)          : 223.13
# Acc / Prec / Rec / F1 (%):  96.79 / 98.01 / 95.05 / 96.51
# T_com (ms)              : 6726593.97
# S_com (MB)              : 8.93
#
# ======================================================================
# Running experiment with N = 100000 (Number of Samples = 20)
# ======================================================================
# Epoch 1/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - accuracy: 0.8810 - loss: 0.3407 - val_accuracy: 0.9054 - val_loss: 0.2370
# Epoch 2/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9302 - loss: 0.1941 - val_accuracy: 0.9457 - val_loss: 0.1596
# Epoch 3/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9469 - loss: 0.1612 - val_accuracy: 0.9495 - val_loss: 0.1465
# Epoch 4/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9521 - loss: 0.1390 - val_accuracy: 0.9498 - val_loss: 0.1412
# Epoch 5/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9630 - loss: 0.1088 - val_accuracy: 0.9704 - val_loss: 0.0933
# Epoch 6/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9726 - loss: 0.0841 - val_accuracy: 0.9687 - val_loss: 0.0868
# Epoch 7/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9768 - loss: 0.0707 - val_accuracy: 0.9813 - val_loss: 0.0606
# Epoch 8/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9803 - loss: 0.0630 - val_accuracy: 0.9819 - val_loss: 0.0593
# Epoch 9/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9817 - loss: 0.0588 - val_accuracy: 0.9816 - val_loss: 0.0626
# Epoch 10/10
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9834 - loss: 0.0551 - val_accuracy: 0.9826 - val_loss: 0.0615
# REF_COUNT used          : 20
# Train time (s)          : 246.82
# Acc / Prec / Rec / F1 (%):  98.26 / 99.40 / 96.83 / 98.10
# T_com (ms)              : 7150945.66
# S_com (MB)              : 9.92

# %%
display_results_table(results)
# Out:
# ========================================================================================================================
# Experiment Results With Number of Samples (20)
# ========================================================================================================================
# Instances  Number of Samples Acc (%)  Prec (%)  Rec (%)  F1 (%)   Train(s)  T_com(ms)  S_com(MB)
# ------------------------------------------------------------------------------------------------------------------------
# 10000      20         90.10    90.10    85.98     94.37    89.98    34.43     707123.28  0.99      3.82
# 20000      20         93.75    93.75    90.25     97.04    93.53    56.95     1551582.34 1.99      2.06
# 30000      20         95.42    95.42    96.00     94.11    95.04    80.85     2233988.29 2.98      4.00
# 40000      20         96.31    96.31    97.55     94.50    96.00    104.04    2885450.36 3.97      2.37
# 50000      20         94.59    94.59    96.17     92.13    94.11    127.38    3650054.93 4.96      4.37
# 60000      20         96.55    96.55    96.80     95.80    96.29    151.72    4254438.40 5.95      2.80
# 70000      20         97.36    97.36    98.22     96.09    97.15    174.36    5077365.88 6.94      4.64
# 80000      20         98.04    98.04    98.40     97.39    97.89    199.01    5716564.18 7.94      2.95
# 90000      20         96.79    96.79    98.01     95.05    96.51    223.13    6726593.97 8.93      4.98
# 100000     20         98.26    98.26    99.40     96.83    98.10    246.82    7150945.66 9.92      3.37

# %%
import matplotlib.pyplot as plt

for i, hist in enumerate(results['history']):
    n = results['instances'][i]

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(hist['accuracy'], label='Train Accuracy')
    axes[0].plot(hist['val_accuracy'], label='Val Accuracy')
    axes[0].set_title(f'Accuracy - {n//1000}k instances')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(False)

    axes[1].plot(hist['loss'], label='Train Loss')
    axes[1].plot(hist['val_loss'], label='Val Loss')
    axes[1].set_title(f'Loss - {n//1000}k instances')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(False)

    plt.tight_layout()
    plt.show()
